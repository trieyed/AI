# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Creating a pandas dataframe
data = {
    "Name":["Ram","Hari","Sita"],
    "Age":[21,22,23],
    "City":["Kathmandu","Pokhara","Mumbai"],
    "Country":["Nepal","Nepal","India"]

}
df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age       City Country
# 0   Ram   21  Kathmandu   Nepal
# 1  Hari   22    Pokhara   Nepal
# 2  Sita   23     Mumbai   India

# %%
#Create a pandas dataframe with values [10,20,30,40] and names["A","B","C","D"]
data1 = {
    "A":[10],
    "B":[20],
    "C":[30],
    "D":[40],
}
df1 = pd.DataFrame(data1)
print(df1)
# Out:
#     A   B   C   D
# 0  10  20  30  40

# %%
#Creating a pandas dataframe
data = {
    "Name":["Ram","Hari","Sita"],
    "Age":[21,22,23],
    "City":["Kathmandu","Pokhara","Mumbai"],
    "Country":["Nepal","Nepal","India"]

}
df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age       City Country
# 0   Ram   21  Kathmandu   Nepal
# 1  Hari   22    Pokhara   Nepal
# 2  Sita   23     Mumbai   India

# %%
#Create a damtaframe with columns "City" (["Paris","Tokyo","Sydney"]) and "Population ([2,1.37.4,5.3])".
# Print the dataframe.

# %%
data2 = {
    "City":["Paris","Tokyo","Sydney"],
    "Population":[2,1.37,5.3]
}
df2 = pd.DataFrame(data2)
print(df2.to_string(index=False))
# Out:
#   City  Population
#  Paris        2.00
#  Tokyo        1.37
# Sydney        5.30

# %%
#Filtering data in dataframe
data = {
    "Name":["Ram","Hari","Sita"],
    "Age":[21,22,23],
    "City":["Kathmandu","Pokhara","Mumbai"],
    "Country":["Nepal","Nepal","India"]

}
df = pd.DataFrame(data)
df[df["Age"]>21]
# print(df.to_string(index=False))
# Out:
#    Name  Age     City Country
# 1  Hari   22  Pokhara   Nepal
# 2  Sita   23   Mumbai   India

# %%
#Reading and Processing a CSV file
import io
#Creating a csv file
csv_data = """
Name,Age,City,Country
Ram,21,Kathmandu,Nepal
Hari,22,Pokhara,Nepal
Sita,23,Mumbai,India
"""
#Reading a csv file
df = pd.read_csv(io.StringIO(csv_data))
print(df)

#Calculate average age
average_age = df["Age"].mean()
print("Average age:",average_age)
# Out:
#    Name  Age       City Country
# 0   Ram   21  Kathmandu   Nepal
# 1  Hari   22    Pokhara   Nepal
# 2  Sita   23     Mumbai   India
# Average age: 22.0

# %%
df.head()
# Out:
#    Name  Age       City Country
# 0   Ram   21  Kathmandu   Nepal
# 1  Hari   22    Pokhara   Nepal
# 2  Sita   23     Mumbai   India

# %%
df.tail()
# Out:
#    Name  Age       City Country
# 0   Ram   21  Kathmandu   Nepal
# 1  Hari   22    Pokhara   Nepal
# 2  Sita   23     Mumbai   India

# %%
#Task 4 : Simulate a CSV string with columns product apple banana and orange and price 1.0, 0.5, 0,75 .
#Read it into a dataframe and print the sum of price using df["Price"].sum()
